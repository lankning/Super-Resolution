# %%
import Sakuya_arch
import torch

# %%
model = Sakuya_arch.LunaTokis(32, 1, 4, 1, 1)
# nf=64, nframes=3, groups=4, front_RBs=1, back_RBs=1
print('STVSR parameters:%.2fMb' % (sum(param.numel() for param in model.parameters())/1000000))
# Out:
# STVSR parameters:2.05Mb

# %%
print('STVSR Structure\n',model)
# Out:
# STVSR Structure
#  LunaTokis(
#   (conv_first): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (feature_extraction): Sequential(
#     (0): ResidualBlock_noBN(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (fea_L2_conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (fea_L2_conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fea_L3_conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (fea_L3_conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pcd_align): PCD_Align(
#     (L3_offset_conv1_1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (L3_offset_conv2_1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (L3_dcnpack_1): DCN_sep(
# ...

# %%
cuda = torch.cuda.is_available()
if cuda:
    print('Is cuda available:',cuda)
    model.cuda()
# Out:
# Is cuda available: True

# %% [markdown]
# https://zhuanlan.zhihu.com/p/74722043
#
# https://pytorch.org/tutorials/beginner/basics/intro.html
